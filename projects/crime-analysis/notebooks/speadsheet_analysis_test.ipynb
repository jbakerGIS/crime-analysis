# %% [markdown]
# # Spreadsheet Analysis
# ### Testing various methods for analyzing and editing the election results spreadsheet

# %%
import pandas as pd
import numpy as np

# %%
# Read spreadsheet into dataframe
df = pd.read_csv(r"C:\Users\viver\Documents\git\gis-portfolio\projects\crime-analysis\data\intermediate\election_2012_data_cleaned.csv")
df.head()
# Out:
#         STATE TOTAL_VOTES Democratic_Votes Democratic_Percent  Democratic_EV  \
# 0     Alabama   2,074,338          795,696             38.40%            NaN
# 1      Alaska     300,495          122,640             40.80%            NaN
# 2     Arizona   2,299,254        1,025,232             44.60%            NaN
# 3    Arkansas   1,069,468          394,409             36.90%            NaN
# 4  California  13,038,547        7,854,285             60.20%           55.0
#
#   Republican_Votes Republican_Percent  Republican_EV  Others_Votes  \
# 0        1,255,925             60.50%            9.0           NaN
# 1          164,676             54.80%            3.0           NaN
# 2        1,233,654             53.70%           11.0           NaN
# 3          647,744             60.60%            6.0           NaN
# 4        4,839,958             37.10%            NaN           NaN
#
#    Others_Percent  Others_EV
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN

# %%
# Make new column for use in ArcPro
df['Political_Party_Voting_Results'] = np.where(df['Democratic_Votes'] > df['Republican_Votes'], 'Democrat', 'Republican')
df.head()
# Out:
#         STATE TOTAL_VOTES Democratic_Votes Democratic_Percent  Democratic_EV  \
# 0     Alabama   2,074,338          795,696             38.40%            NaN
# 1      Alaska     300,495          122,640             40.80%            NaN
# 2     Arizona   2,299,254        1,025,232             44.60%            NaN
# 3    Arkansas   1,069,468          394,409             36.90%            NaN
# 4  California  13,038,547        7,854,285             60.20%           55.0
#
#   Republican_Votes Republican_Percent  Republican_EV  Others_Votes  \
# 0        1,255,925             60.50%            9.0           NaN
# 1          164,676             54.80%            3.0           NaN
# 2        1,233,654             53.70%           11.0           NaN
# 3          647,744             60.60%            6.0           NaN
# 4        4,839,958             37.10%            NaN           NaN
#
#    Others_Percent  Others_EV Political_Party_Voting_Results
# 0             NaN        NaN                       Democrat
# 1             NaN        NaN                     Republican
# 2             NaN        NaN                     Republican
# 3             NaN        NaN                     Republican
# 4             NaN        NaN                       Democrat

# %%
# Write function to add voting results column
def add_voting_results_column(df):
    """
    Adds a new column 'Political_Party_Voting_Results' to the dataframe
    based on the comparison of 'Democratic_Votes' and 'Republican_Votes'.

    Parameters:
    df (pd.DataFrame): DataFrame containing 'Democratic_Votes' and 'Republican_Votes' columns.

    Returns:
    pd.DataFrame: DataFrame with the new column added.
    """
    
    df['Political_Party_Voting_Results'] = np.where(
        df['Democratic_Votes'] > df['Republican_Votes'], 
        'Democrat', 
        'Republican'
    )
    return df

# %%
# Apply function to multiple CSV files
file_path = r"C:\Users\viver\Documents\git\gis-portfolio\projects\crime-analysis\data\intermediate"
csv_list = ['\election_2012_data_cleaned.csv', '\election_2016_data_cleaned.csv', '\election_2020_data_cleaned.csv', '\election_2024_data_cleaned.csv']
for csv in csv_list:
    df = pd.read_csv(file_path + csv)
    add_voting_results_column(df)
    df.head()
    df.to_csv(file_path + csv, index=False)

# %%
# Test dictionary logic
csv = r"C:\Users\viver\Documents\git\gis-portfolio\projects\crime-analysis\data\intermediate\election_2012_data_cleaned.csv"
df = pd.read_csv(csv)
results_list = []
for row in df.itertuples():
    results_list.append({
        "state": row.STATE,
        "voting_result": row.Political_Party_Voting_Results
    })
print(results_list)
# Out:
# [{'state': 'Alabama', 'voting_result': 'Democrat'}, {'state': 'Alaska', 'voting_result': 'Republican'}, {'state': 'Arizona', 'voting_result': 'Republican'}, {'state': 'Arkansas', 'voting_result': 'Republican'}, {'state': 'California', 'voting_result': 'Democrat'}, {'state': 'Colorado', 'voting_result': 'Democrat'}, {'state': 'Connecticut', 'voting_result': 'Democrat'}, {'state': 'Delaware', 'voting_result': 'Democrat'}, {'state': 'Dist. of Col.', 'voting_result': 'Democrat'}, {'state': 'Florida', 'voting_result': 'Democrat'}, {'state': 'Georgia', 'voting_result': 'Republican'}, {'state': 'Hawaii', 'voting_result': 'Democrat'}, {'state': 'Idaho', 'voting_result': 'Republican'}, {'state': 'Illinois', 'voting_result': 'Democrat'}, {'state': 'Indiana', 'voting_result': 'Republican'}, {'state': 'Iowa', 'voting_result': 'Democrat'}, {'state': 'Kansas', 'voting_result': 'Republican'}, {'state': 'Kentucky', 'voting_result': 'Democrat'}, {'state': 'Louisiana', 'voting_result': 'Democrat'}, {'state': 'Maine', 'voting_result': 'Democrat'}, {'state': 'Maryland', 'voting_result': 'Republican'}, {'state': 'Massachusetts', 'voting_result': 'Democrat'}, {'state': 'Michigan', 'voting_result': 'Democrat'}, {'state': 'Minnesota', 'voting_result': 'Democrat'}, {'state': 'Mississippi', 'voting_result': 'Republican'}, {'state': 'Missouri', 'voting_result': 'Republican'}, {'state': 'Montana', 'voting_result': 'Republican'}, {'state': 'Nebraska', 'voting_result': 'Republican'}, {'state': 'Nevada', 'voting_result': 'Democrat'}, {'state': 'New Hampshire', 'voting_result': 'Democrat'}, {'state': 'New Jersey', 'voting_result': 'Democrat'}, {'state': 'New Mexico', 'voting_result': 'Democrat'}, {'state': 'New York', 'voting_result': 'Democrat'}, {'state': 'North Carolina', 'voting_result': 'Republican'}, {'state': 'North Dakota', 'voting_result': 'Republican'}, {'state': 'Ohio', 'voting_result': 'Democrat'}, {'state': 'Oklahoma', 'voting_result': 'Republican'}, {'state': 'Oregon', 'voting_result': 'Democrat'}, {'state': 'Pennsylvania', 'voting_result': 'Democrat'}, {'state': 'Rhode Island', 'voting_result': 'Democrat'}, {'state': 'South Carolina', 'voting_result': 'Democrat'}, {'state': 'South Dakota', 'voting_result': 'Republican'}, {'state': 'Tennessee', 'voting_result': 'Democrat'}, {'state': 'Texas', 'voting_result': 'Republican'}, {'state': 'Utah', 'voting_result': 'Republican'}, {'state': 'Vermont', 'voting_result': 'Republican'}, {'state': 'Virginia', 'voting_result': 'Democrat'}, {'state': 'Washington', 'voting_result': 'Democrat'}, {'state': 'West Virginia', 'voting_result': 'Republican'}, {'state': 'Wisconsin', 'voting_result': 'Democrat'}, {'state': 'Wyoming', 'voting_result': 'Democrat'}]

# %%
# Create dictionary of all election years' results
state_results = {}
for csv in csv_list:
    df = pd.read_csv(file_path + csv)
    for row in df.itertuples():
        if row.STATE not in state_results:
            state_results[row.STATE] = []
        state_results[row.STATE].append(row.Political_Party_Voting_Results)

print(state_results)
# Out:
# {'Alabama': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Alaska': ['Republican', 'Republican', 'Republican', 'Republican'], 'Arizona': ['Republican', 'Republican', 'Democrat', 'Republican'], 'Arkansas': ['Republican', 'Republican', 'Republican', 'Republican'], 'California': ['Democrat', 'Democrat', 'Republican', 'Democrat'], 'Colorado': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Connecticut': ['Democrat', 'Democrat', 'Republican', 'Democrat'], 'Delaware': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Dist. of Col.': ['Democrat', 'Democrat'], 'Florida': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Georgia': ['Republican', 'Republican', 'Democrat', 'Republican'], 'Hawaii': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Idaho': ['Republican', 'Republican', 'Republican', 'Republican'], 'Illinois': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Indiana': ['Republican', 'Republican', 'Republican', 'Republican'], 'Iowa': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Kansas': ['Republican', 'Republican', 'Republican', 'Republican'], 'Kentucky': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Louisiana': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Maine': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Maryland': ['Republican', 'Republican', 'Republican', 'Democrat'], 'Massachusetts': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Michigan': ['Democrat', 'Republican', 'Democrat', 'Republican'], 'Minnesota': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Mississippi': ['Republican', 'Republican', 'Republican', 'Republican'], 'Missouri': ['Republican', 'Republican', 'Republican', 'Republican'], 'Montana': ['Republican', 'Republican', 'Republican', 'Republican'], 'Nebraska': ['Republican', 'Republican', 'Republican', 'Republican'], 'Nevada': ['Democrat', 'Democrat', 'Democrat', 'Republican'], 'New Hampshire': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'New Jersey': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'New Mexico': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'New York': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'North Carolina': ['Republican', 'Republican', 'Republican', 'Republican'], 'North Dakota': ['Republican', 'Democrat', 'Republican', 'Republican'], 'Ohio': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Oklahoma': ['Republican', 'Republican', 'Democrat', 'Democrat'], 'Oregon': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Pennsylvania': ['Democrat', 'Republican', 'Democrat', 'Republican'], 'Rhode Island': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'South Carolina': ['Democrat', 'Democrat', 'Republican', 'Republican'], 'South Dakota': ['Republican', 'Republican', 'Republican', 'Republican'], 'Tennessee': ['Democrat', 'Democrat', 'Republican', 'Republican'], 'Texas': ['Republican', 'Republican', 'Republican', 'Republican'], 'Utah': ['Republican', 'Republican', 'Republican', 'Republican'], 'Vermont': ['Republican', 'Republican', 'Democrat', 'Democrat'], 'Virginia': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Washington': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'West Virginia': ['Republican', 'Republican', 'Republican', 'Republican'], 'Wisconsin': ['Democrat', 'Republican', 'Democrat', 'Republican'], 'Wyoming': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'District of Columbia': ['Democrat', 'Democrat']}

# %%
# Attempting setdefault() method
state_results = {}
for csv in csv_list:    
    df = pd.read_csv(file_path + csv)
    for row in df.itertuples():
        state_results.setdefault(row.STATE, []).append(row.Political_Party_Voting_Results)

print(state_results)
# Out:
# {'Alabama': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Alaska': ['Republican', 'Republican', 'Republican', 'Republican'], 'Arizona': ['Republican', 'Republican', 'Democrat', 'Republican'], 'Arkansas': ['Republican', 'Republican', 'Republican', 'Republican'], 'California': ['Democrat', 'Democrat', 'Republican', 'Democrat'], 'Colorado': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Connecticut': ['Democrat', 'Democrat', 'Republican', 'Democrat'], 'Delaware': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Dist. of Col.': ['Democrat', 'Democrat'], 'Florida': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Georgia': ['Republican', 'Republican', 'Democrat', 'Republican'], 'Hawaii': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Idaho': ['Republican', 'Republican', 'Republican', 'Republican'], 'Illinois': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Indiana': ['Republican', 'Republican', 'Republican', 'Republican'], 'Iowa': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Kansas': ['Republican', 'Republican', 'Republican', 'Republican'], 'Kentucky': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Louisiana': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Maine': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Maryland': ['Republican', 'Republican', 'Republican', 'Democrat'], 'Massachusetts': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Michigan': ['Democrat', 'Republican', 'Democrat', 'Republican'], 'Minnesota': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Mississippi': ['Republican', 'Republican', 'Republican', 'Republican'], 'Missouri': ['Republican', 'Republican', 'Republican', 'Republican'], 'Montana': ['Republican', 'Republican', 'Republican', 'Republican'], 'Nebraska': ['Republican', 'Republican', 'Republican', 'Republican'], 'Nevada': ['Democrat', 'Democrat', 'Democrat', 'Republican'], 'New Hampshire': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'New Jersey': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'New Mexico': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'New York': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'North Carolina': ['Republican', 'Republican', 'Republican', 'Republican'], 'North Dakota': ['Republican', 'Democrat', 'Republican', 'Republican'], 'Ohio': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Oklahoma': ['Republican', 'Republican', 'Democrat', 'Democrat'], 'Oregon': ['Democrat', 'Republican', 'Republican', 'Republican'], 'Pennsylvania': ['Democrat', 'Republican', 'Democrat', 'Republican'], 'Rhode Island': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'South Carolina': ['Democrat', 'Democrat', 'Republican', 'Republican'], 'South Dakota': ['Republican', 'Republican', 'Republican', 'Republican'], 'Tennessee': ['Democrat', 'Democrat', 'Republican', 'Republican'], 'Texas': ['Republican', 'Republican', 'Republican', 'Republican'], 'Utah': ['Republican', 'Republican', 'Republican', 'Republican'], 'Vermont': ['Republican', 'Republican', 'Democrat', 'Democrat'], 'Virginia': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'Washington': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'West Virginia': ['Republican', 'Republican', 'Republican', 'Republican'], 'Wisconsin': ['Democrat', 'Republican', 'Democrat', 'Republican'], 'Wyoming': ['Democrat', 'Democrat', 'Democrat', 'Democrat'], 'District of Columbia': ['Democrat', 'Democrat']}

# %%
# Find the most common voting result for a test list using Counter
from collections import Counter

test_list = ['democrat', 'republican', 'democrat', 'democrat']
counter = Counter(test_list)
most_common = counter.most_common(1)
print(most_common)
# Out:
# [('democrat', 3)]

# %%
# Alternative method without Counter
dem_count = test_list.count('democrat')
rep_count = test_list.count('republican')
if dem_count > rep_count:
    print('democrat')
elif rep_count > dem_count:
    print('republican')
else:
    print('tie')
# Out:
# democrat
